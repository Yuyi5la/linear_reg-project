# 64                                                          21    1457034     3326
# 65                                    Rush - Moody Jones Remix    1455106      620
# 66                                                  In Between    1445230      776
# 67                                                        Amin    1415579      826
# 68                                          1942 (feat. Milar)    1337368     2835
# 69                                                        DITR    1265529      506
# 70                                                         Ase    1262991      972
# 71                                           Away - Lilo Remix    1237494      211
# 72                                                         Ija    1153862      362
# 73                                        The Kids Are Alright    1098147     1757
# 74                                     Gara (feat. Ayra Starr)    1020275     1962
# 75                                              Worth My While    1018164      259
# 76                         My Love (feat. Ayra Starr & Jireel)     975266      649
# 77                                           Big FU - Extended     965623      714
# 78                                          Skinny Girl Anthem     771541      452
# 79                                                     Jamming     755012      452
# 80                                                       Stars     713711      175
# 81                    My Love (feat. Ayra Starr) - BUNT. Remix     688867     1304
# 82                                      Ija - TOKiMONSTA Remix     583416       79
# 83                                                    Ooh Lala     578495      257
# 84                                              Rush (Sped Up)     556842      937
# 85                                     Santa - Sped Up Version     522487     2177
# 86     You're Hired (feat. Ayra Starr) - Legendury Beatz Remix     494652      243
# 87                                          Sability (Sped Up)     354361      485
# 88                               PINACOLADA (Shaken) - Sped up     329882     4016
# 89              You're Hired (feat. Ayra Starr) - Ginchy Remix     188684      169
# 90  My Love (feat. Ayra Starr and BEAM) - Crate Classics Remix     152072      169
# 91             My Love (feat. Ayra Starr) - DJ Maphorisa Remix     138580      156

# %%
df = df [['Streams','Daily']]

# %%
df
# Out:
#       Streams    Daily
# 0   486956514  1803195
# 1   413947267   282747
# 2   108324908    96603
# 3    83341131    38967
# 4    77772456   183146
# ..        ...      ...
# 87     354361      485
# 88     329882     4016
# 89     188684      169
# 90     152072      169
# 91     138580      156
#
# [92 rows x 2 columns]

# %%
x = df ['Daily']
y = df ['Streams']

# %%
plt.scatter(x,y)
plt.xlabel('Daily')
plt.ylabel('Streams')
plt.xscale('log')
plt.yscale('log')

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['Streams'], df['Daily'], alpha=0.6, edgecolors='w', s=100)
plt.title('Scatter Plot of Streams vs Daily')
plt.xlabel('Streams')
plt.ylabel('Daily')
plt.xscale('log')  # Log scale for better visualization
plt.yscale('log')  # Log scale for better visualization
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.4,random_state=23)

# %%
x_train
# Out:
# 34      50922
# 72        362
# 82         79
# 89        169
# 0     1803195
# 14      36567
# 30     182992
# 87        485
# 38       4566
# 86        243
# 13     104250
# 32       4244
# 35     112597
# 44       2076
# 10      35924
# 2       96603
# 84        937
# 88       4016
# 68       2835
# 65        620
# 22       7929
# 77        714
# 43       1712
# 52       1490
# 70        972
# 1      282747
# 36      24258
# 15      11409
# 85       2177
# 59        813
# 33       3457
# 19      19738
# 57        383
# 62        319
# 41       5125
# 48       5662
# 21      27017
# 80        175
# 64       3326
# 69        506
# 75        259
# 66        776
# 49       3685
# 12      26757
# 45       1123
# 6       35214
# 51        940
# 25       7542
# 39        945
# 76        649
# 31       4821
# 54       5802
# 73       1757
# 40       3218
# 83        257
# Name: Daily, dtype: int64

# %%
x_train= np.array (x_train).reshape (-1,1)
x_train
# Out:
# array([[  50922],
#        [    362],
#        [     79],
#        [    169],
#        [1803195],
#        [  36567],
#        [ 182992],
#        [    485],
#        [   4566],
#        [    243],
#        [ 104250],
#        [   4244],
#        [ 112597],
#        [   2076],
#        [  35924],
#        [  96603],
#        [    937],
#        [   4016],
#        [   2835],
#        [    620],
#        [   7929],
#        [    714],
#        [   1712],
#        [   1490],
#        [    972],
#        [ 282747],
#        [  24258],
#        [  11409],
#        [   2177],
#        [    813],
#        [   3457],
#        [  19738],
#        [    383],
#        [    319],
#        [   5125],
#        [   5662],
#        [  27017],
#        [    175],
#        [   3326],
#        [    506],
#        [    259],
#        [    776],
#        [   3685],
#        [  26757],
#        [   1123],
#        [  35214],
#        [    940],
#        [   7542],
#        [    945],
#        [    649],
#        [   4821],
#        [   5802],
#        [   1757],
#        [   3218],
#        [    257]])

# %%
x_test= np.array (x_test).reshape (-1,1)
x_test
# Out:
# array([[  5998],
#        [   747],
#        [  1411],
#        [ 38967],
#        [   826],
#        [ 47364],
#        [  1962],
#        [  5160],
#        [ 13998],
#        [  2840],
#        [ 10984],
#        [   211],
#        [  8043],
#        [ 52161],
#        [ 26274],
#        [ 17891],
#        [183146],
#        [   452],
#        [ 37428],
#        [   809],
#        [  4980],
#        [ 74152],
#        [   156],
#        [173211],
#        [ 20727],
#        [  1337],
#        [  7898],
#        [   169],
#        [ 14056],
#        [  3175],
#        [  1166],
#        [ 11767],
#        [   871],
#        [   452],
#        [   488],
#        [   921],
#        [  1304]])

# %%
lr = LinearRegression()

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (55, 1)
# (55,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c=lr.intercept_
c
# Out:
# np.float64(10463944.358606305)

# %%
m = lr.coef_
m
# Out:
# array([290.17150093])

# %%
y_pred=lr.predict(x_train)
y_pred
# Out:
# array([2.52400575e+07, 1.05689864e+07, 1.04868679e+07, 1.05129833e+07,
#        5.33699744e+08, 2.10746456e+07, 6.35630077e+07, 1.06046775e+07,
#        1.17888674e+07, 1.05344560e+07, 4.07143233e+07, 1.16954322e+07,
#        4.31363848e+07, 1.10663404e+07, 2.08880654e+07, 3.84953819e+07,
#        1.07358351e+07, 1.16292731e+07, 1.12865806e+07, 1.06438507e+07,
#        1.27647142e+07, 1.06711268e+07, 1.09607180e+07, 1.08962999e+07,
#        1.07459911e+07, 9.25090657e+07, 1.75029246e+07, 1.37745110e+07,
#        1.10956477e+07, 1.06998538e+07, 1.14670672e+07, 1.61913494e+07,
#        1.05750800e+07, 1.05565091e+07, 1.19510733e+07, 1.21068954e+07,
#        1.83035078e+07, 1.05147244e+07, 1.14290548e+07, 1.06107711e+07,
#        1.05390988e+07, 1.06891174e+07, 1.15332263e+07, 1.82280632e+07,
#        1.07898070e+07, 2.06820436e+07, 1.07367056e+07, 1.26524178e+07,
#        1.07381564e+07, 1.06522657e+07, 1.18628612e+07, 1.21475194e+07,
#        1.09737757e+07, 1.13977162e+07, 1.05385184e+07])

# %%
print(np.min(x_train), np.min(y_train))
# Out:
# 79 188684

# %%
print(np.min(y_pred))
# Out:
# 10486867.90717953

# %%
x_train_flat = x_train.flatten()

# %%
print(np.min(y_pred))
# Out:
# 10486867.90717953

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,y_pred,color = 'red')
plt.xlabel("Streams")
plt.ylabel("Daily")
plt.xscale('log')  # Log scale for better visualization
plt.yscale('log')
